# %%
import requests 
import pandas as pd

# %%
root = 'https://collectionapi.metmuseum.org'
path = '/public/collection/v1/search'
parameter ='?q=sustainable'

# %%
root + path + parameter
# Out:
# 'https://collectionapi.metmuseum.org/public/collection/v1/search?q=sustainable'

# %%
data = requests.get(root + path + parameter)

# %%
data
# Out:
# <Response [200]>

# %%
dir(data)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
data.content
# Out:
# b'{"total":288,"objectIDs":[829789,473770,188827,473769,698529,890008,191081,812711,20895,20894,81108,470313,82880,254576,19948,490145,575557,440386,313654,468346,78910,785496,785466,492777,661423,450753,470602,544232,311237,435864,468230,715551,642422,889938,448649,310325,715529,75745,715550,715554,715556,715558,715552,452575,392513,715555,715553,545875,830453,701903,545442,744610,547789,19928,53167,20345,19987,20070,715530,428696,835298,20071,207263,207017,206996,53172,436101,437001,236643,503279,197434,81102,83294,207394,471980,822499,460913,838928,195180,816522,450991,436244,435933,157288,83084,265529,83083,838927,838926,838929,81483,772167,451401,394659,94439,818018,500589,725932,77761,79573,73294,77801,269404,755083,412502,744270,207799,395242,427045,205741,438466,437518,436997,437224,839222,14038,839223,839220,310919,399141,640950,696538,735361,40277,302505,312287,702001,702000,849866,839230,326399,701997,701977,72769,86436,657429,326155,500626,204504,271942,271944,271945,436885,436884,904873,385603,436282,404896,174593,325996,326398,591346,852838,227765,904846,306226,404907,283131,45749,450594,222132,504295,503447,207021,325974,325998,325976,325971,326152,326151,326153,326154,591323,319853,283160,626669,76485,789578,500527,325973,771695,439327,318430,749845,358343,325999,325970,325997,326149,326150,326454,318050,325969,309415,309416,325966,325965,325963,325968,325964,325967,325960,325959,325961,325962,326396,326397,24305,313662,311946,326148,339695,316433,690570,311158,207335,49450,325958,665683,504265,314954,503904,314955,266948,875741,502327,828118,436271,450588,437427,361968,702004,701991,701999,701995,701996,701998,702002,701992,702003,701994,751273,436106,823230,318320,822572,822575,822573,822574,287286,17308,78470,313364,454353,436433,446951,448222,437359,291652,291654,268933,727762,309972,320324,291651,291655,291653,302667,504608,786189,283073,40311,437207,503042,368003,420674,206759,206758,684855,198799,436047,837980,203749,888338,203915,436848,362751,761306]}'

# %%
parsed = data.json()

# %%
parsed
# Out:
# {'total': 288,
#  'objectIDs': [829789,
#   473770,
#   188827,
#   473769,
#   698529,
#   890008,
#   191081,
#   812711,
#   20895,
#   20894,
#   81108,
#   470313,
#   82880,
#   254576,
#   19948,
#   490145,
#   575557,
#   440386,
#   313654,
#   468346,
#   78910,
#   785496,
#   785466,
#   492777,
#   661423,
#   450753,
#   470602,
#   544232,
#   311237,
#   435864,
#   468230,
#   715551,
#   642422,
#   889938,
#   448649,
#   310325,
#   715529,
#   75745,
#   715550,
#   715554,
#   715556,
#   715558,
#   715552,
#   452575,
#   392513,
#   715555,
#   715553,
#   545875,
#   830453,
#   701903,
#   545442,
#   744610,
#   547789,
#   19928,
#   53167,
#   20345,
#   19987,
#   20070,
#   715530,
#   428696,
#   835298,
#   20071,
#   207263,
#   207017,
#   206996,
#   53172,
#   436101,
#   437001,
#   236643,
#   503279,
#   197434,
#   81102,
#   83294,
#   207394,
#   471980,
#   822499,
#   460913,
#   838928,
#   195180,
#   816522,
#   450991,
#   436244,
#   435933,
#   157288,
#   83084,
#   265529,
#   83083,
#   838927,
#   838926,
#   838929,
#   81483,
#   772167,
#   451401,
#   394659,
#   94439,
#   818018,
#   500589,
#   725932,
#   77761,
#   79573,
#   73294,
#   77801,
#   269404,
#   755083,
#   412502,
#   744270,
#   207799,
#   395242,
#   427045,
#   205741,
#   438466,
#   437518,
#   436997,
#   437224,
#   839222,
#   14038,
#   839223,
#   839220,
#   310919,
#   399141,
#   640950,
#   696538,
#   735361,
#   40277,
#   302505,
#   312287,
#   702001,
#   702000,
#   849866,
#   839230,
#   326399,
#   701997,
#   701977,
#   72769,
#   86436,
#   657429,
#   326155,
#   500626,
#   204504,
#   271942,
#   271944,
#   271945,
#   436885,
#   436884,
#   904873,
#   385603,
#   436282,
#   404896,
#   174593,
#   325996,
#   326398,
#   591346,
#   852838,
#   227765,
#   904846,
#   306226,
#   404907,
#   283131,
#   45749,
#   450594,
#   222132,
#   504295,
#   503447,
#   207021,
#   325974,
#   325998,
#   325976,
#   325971,
#   326152,
#   326151,
#   326153,
#   326154,
#   591323,
#   319853,
#   283160,
#   626669,
#   76485,
#   789578,
#   500527,
#   325973,
#   771695,
#   439327,
#   318430,
#   749845,
#   358343,
#   325999,
#   325970,
#   325997,
#   326149,
#   326150,
#   326454,
#   318050,
#   325969,
#   309415,
#   309416,
#   325966,
#   325965,
#   325963,
#   325968,
#   325964,
#   325967,
#   325960,
#   325959,
#   325961,
#   325962,
#   326396,
#   326397,
#   24305,
#   313662,
#   311946,
#   326148,
#   339695,
#   316433,
#   690570,
#   311158,
#   207335,
#   49450,
#   325958,
#   665683,
#   504265,
#   314954,
#   503904,
#   314955,
#   266948,
#   875741,
#   502327,
#   828118,
#   436271,
#   450588,
#   437427,
#   361968,
#   702004,
#   701991,
#   701999,
#   701995,
#   701996,
#   701998,
#   702002,
#   701992,
#   702003,
#   701994,
#   751273,
#   436106,
#   823230,
#   318320,
#   822572,
#   822575,
#   822573,
#   822574,
#   287286,
#   17308,
#   78470,
#   313364,
#   454353,
#   436433,
#   446951,
#   448222,
#   437359,
#   291652,
#   291654,
#   268933,
#   727762,
#   309972,
#   320324,
#   291651,
#   291655,
#   291653,
#   302667,
#   504608,
#   786189,
#   283073,
#   40311,
#   437207,
#   503042,
#   368003,
#   420674,
#   206759,
#   206758,
#   684855,
#   198799,
#   436047,
#   837980,
#   203749,
#   888338,
#   203915,
#   436848,
#   362751,
#   761306]}

# %%
objectids = parsed['objectIDs']

# %%
first = objectids[0]

# %%
first
# Out:
# 829789

# %%
dir(parsed)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
objectids
# Out:
# [829789,
#  473770,
#  188827,
#  473769,
#  698529,
#  890008,
#  191081,
#  812711,
#  20895,
#  20894,
#  81108,
#  470313,
#  82880,
#  254576,
#  19948,
#  490145,
#  575557,
#  440386,
#  313654,
#  468346,
#  78910,
#  785496,
#  785466,
#  492777,
#  661423,
#  450753,
#  470602,
#  544232,
#  311237,
#  435864,
#  468230,
#  715551,
#  642422,
#  889938,
#  448649,
#  310325,
#  715529,
#  75745,
#  715550,
#  715554,
#  715556,
#  715558,
#  715552,
#  452575,
#  392513,
#  715555,
#  715553,
#  545875,
#  830453,
#  701903,
#  545442,
#  744610,
#  547789,
#  19928,
#  53167,
#  20345,
#  19987,
#  20070,
#  715530,
#  428696,
#  835298,
#  20071,
#  207263,
#  207017,
#  206996,
#  53172,
#  436101,
#  437001,
#  236643,
#  503279,
#  197434,
#  81102,
#  83294,
#  207394,
#  471980,
#  822499,
#  460913,
#  838928,
#  195180,
#  816522,
#  450991,
#  436244,
#  435933,
#  157288,
#  83084,
#  265529,
#  83083,
#  838927,
#  838926,
#  838929,
#  81483,
#  772167,
#  451401,
#  394659,
#  94439,
#  818018,
#  500589,
#  725932,
#  77761,
#  79573,
#  73294,
#  77801,
#  269404,
#  755083,
#  412502,
#  744270,
#  207799,
#  395242,
#  427045,
#  205741,
#  438466,
#  437518,
#  436997,
#  437224,
#  839222,
#  14038,
#  839223,
#  839220,
#  310919,
#  399141,
#  640950,
#  696538,
#  735361,
#  40277,
#  302505,
#  312287,
#  702001,
#  702000,
#  849866,
#  839230,
#  326399,
#  701997,
#  701977,
#  72769,
#  86436,
#  657429,
#  326155,
#  500626,
#  204504,
#  271942,
#  271944,
#  271945,
#  436885,
#  436884,
#  904873,
#  385603,
#  436282,
#  404896,
#  174593,
#  325996,
#  326398,
#  591346,
#  852838,
#  227765,
#  904846,
#  306226,
#  404907,
#  283131,
#  45749,
#  450594,
#  222132,
#  504295,
#  503447,
#  207021,
#  325974,
#  325998,
#  325976,
#  325971,
#  326152,
#  326151,
#  326153,
#  326154,
#  591323,
#  319853,
#  283160,
#  626669,
#  76485,
#  789578,
#  500527,
#  325973,
#  771695,
#  439327,
#  318430,
#  749845,
#  358343,
#  325999,
#  325970,
#  325997,
#  326149,
#  326150,
#  326454,
#  318050,
#  325969,
#  309415,
#  309416,
#  325966,
#  325965,
#  325963,
#  325968,
#  325964,
#  325967,
#  325960,
#  325959,
#  325961,
#  325962,
#  326396,
#  326397,
#  24305,
#  313662,
#  311946,
#  326148,
#  339695,
#  316433,
#  690570,
#  311158,
#  207335,
#  49450,
#  325958,
#  665683,
#  504265,
#  314954,
#  503904,
#  314955,
#  266948,
#  875741,
#  502327,
#  828118,
#  436271,
#  450588,
#  437427,
#  361968,
#  702004,
#  701991,
#  701999,
#  701995,
#  701996,
#  701998,
#  702002,
#  701992,
#  702003,
#  701994,
#  751273,
#  436106,
#  823230,
#  318320,
#  822572,
#  822575,
#  822573,
#  822574,
#  287286,
#  17308,
#  78470,
#  313364,
#  454353,
#  436433,
#  446951,
#  448222,
#  437359,
#  291652,
#  291654,
#  268933,
#  727762,
#  309972,
#  320324,
#  291651,
#  291655,
#  291653,
#  302667,
#  504608,
#  786189,
#  283073,
#  40311,
#  437207,
#  503042,
#  368003,
#  420674,
#  206759,
#  206758,
#  684855,
#  198799,
#  436047,
#  837980,
#  203749,
#  888338,
#  203915,
#  436848,
#  362751,
#  761306]

# %%
type(objectids)
# Out:
# list

# %%
len(objectids)
# Out:
# 288

# %%
first_ten = []
for item in objectids[:10]:
    url = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{item}'
    response = requests.get(url)
    parsed = response.json()
    first_ten.append(parsed)

# %%
first_ten[-1]
# Out:
# {'objectID': 20894,
#  'isHighlight': True,
#  'accessionNumber': '2011.347',
#  'accessionYear': '2011',
#  'isPublicDomain': False,
#  'primaryImage': '',
#  'primaryImageSmall': '',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 1262,
#    'role': 'Designer',
#    'name': 'Arthur J. Stone',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500104575',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q4799203',
#    'gender': ''},
#   {'constituentID': 9157,
#    'role': 'Maker',
#    'name': 'Herbert Taylor',
#    'constituentULAN_URL': '',
#    'constituentWikidata_URL': '',
#    'gender': ''}],
#  'department': 'The American Wing',
#  'objectName': 'Vase',
#  'title': 'Vase',
#  'culture': 'American',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Designer',
#  'artistPrefix': '',
#  'artistDisplayName': 'Arthur J. Stone',
#  'artistDisplayBio': '1847–1938',
#  'artistSuffix': '',
#  'artistAlphaSort': 'Stone, Arthur J.',
#  'artistNationality': 'American',
#  'artistBeginDate': '1847',
#  'artistEndDate': '1938',
#  'artistGender': '',
#  'artistWikidata_URL': 'https://www.wikidata.org/wiki/Q4799203',
#  'artistULAN_URL': 'http://vocab.getty.edu/page/ulan/500104575',
#  'objectDate': '1915',
#  'objectBeginDate': 1915,
#  'objectEndDate': 1915,
#  'medium': 'silver and gold',
#  'dimensions': '9 3/4 x 8 1/4 in. (24.8 x 21 cm)\r\nLip diameter: 6 1/2 in. (16.5 cm)\r\nBase diameter: 6 3/8 in. (6 3/8 in.)',
#  'measurements': [{'elementName': 'Diam. of base',
#    'elementDescription': None,
#    'elementMeasurements': {'Diameter': 16.192532}},
#   {'elementName': 'Lip diameter',
#    'elementDescription': None,
#    'elementMeasurements': {'Diameter': 16.510033}},
#   {'elementName': 'Overall',
#    'elementDescription': None,
#    'elementMeasurements': {'Diameter': 20.955042, 'Height': 24.765049}}],
#  'creditLine': 'Purchase, Acquisitions Fund; Page and Otto Marx Jr. Foundation and Cranshaw Corporation Gifts, 2011',
#  'geographyType': 'Made in',
#  'city': 'Gardner',
#  'state': 'Massachusetts',
#  'county': '',
#  'country': 'United States',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': '',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2021-04-06T04:41:04.967Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/20894',
#  'tags': None,
#  'objectWikidata_URL': 'https://www.wikidata.org/wiki/Q83562005',
#  'isTimelineWork': True,
#  'GalleryNumber': '706'}

# %%
type(first_ten)
# Out:
# list

# %%
dir(item)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
for item in first_ten:
    title = item.get('artistDisplayName')
    print(title)
# Out:
# None
#
# Lorenzo Bartolini
#
# Jules Tavernier
# Mark Hamasaki
# Auguste Rodin
# Paul Manship
# Arthur J. Stone
# Arthur J. Stone

# %%
first_results = []
for item in objectids[:288]:
    url = f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{item}'
    response = requests.get(url)
    parsed = response.json()
    first_results.append(parsed)

# %%
for item in first_results:
    if item.get('artistDisplayName'):
        print(item['artistDisplayName'])
# Out:
# Lorenzo Bartolini
# Jules Tavernier
# Mark Hamasaki
# Auguste Rodin
# Paul Manship
# Arthur J. Stone
# Arthur J. Stone
# Mme. Grapanche
# Maija Grotell
# Michael Aschenbrenner
# Johann Joachim Faber
# Evelyn De Morgan
# Evelyn De Morgan
# Wifredo Lam
# Nasreen Mohamedi
# Giacomo Ceruti
# Maija Grotell
# Anne Seymour Damer
# Sandy Rodriguez
# Barnes Foundation Master
# Maija Grotell
# Fa Ruozhen
# Maija Grotell
# Maija Grotell
# Maija Grotell
# Maija Grotell
# Maija Grotell
# Claude Mellan
# Maija Grotell
# Maija Grotell
# Wangechi Mutu
# University City Pottery
# University City Pottery
# University City Pottery
# University City Pottery
# Maija Grotell
# Jacob Matham
# Katharine Hamnett London
# University City Pottery
# Antico (Pier Jacopo Alari Bonacolsi)
# Fujiwara no Yukinari (Kōzei)
# Gerard David
# Master of Charles of Durazzo
# Andrea Briosco, called Riccio
# Paul Solanier
# House of Balenciaga
# Madame Grès (Germaine Émilie Krebs)
# Donatello
# Pierre Biard II
# Gan Erke
# Giambologna
# Orsola Maddalena Caccia
# Albrecht Dürer
# Continental Painter
# Weeks
# Alfred Stieglitz
# Gan Erke
# Gan Erke
# Gan Erke
# House of Chanel
# Richard Hamilton
# Carmen Herrera
# Claire McCardell
# Zhan Wang
# Alfred Stieglitz
# Donna Conlon
# Giulio Bonasone
# Thomas Rowlandson
# Sèvres Manufactory
# Claude Mellan
# Bartolomeo Fenice (Fénis)
# Master of the Berswordt Altar
# Théodore Rousseau
# Master of the Berswordt Altar
# Johann Esaias Nilson
# Jin Xiya
# Associated Artists
# Jin Xiya
# Jin Xiya
# William Havell
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Rudolph Ruzicka
# Jin Xiya
# Ernest Eugène Appert
# Ernest Eugène Appert
# Unidentified artist
# Yohji Yamamoto
# Vittore Gambello
# David Levinthal
# David Levinthal
# David Levinthal
# Liberale da Verona
# Liberale da Verona
# George Segal
# Edwin Austin Abbey
# Jan van Eyck
# Byrdcliffe Arts and Crafts Colony
# Lucile Ltd., New York
# Charles Joseph Hullmandel
# Hieronymus (Jerome) Wierix
# Claes Oldenburg
# Hill and Adamson
# Byrdcliffe Arts and Crafts Colony
# Edouard Baldus
# Zhu Yunming
# Séguin et Cie
# John Broadwood & Sons
# Samuel Green
# Francesco Fanelli
# Unknown
# Richard M. Ferris
# Mario De Biasi
# Gerard David
# Gerrit Pietersz. Sweelink
# Giovanni Maria Verdizotti
# Isneg artist
# Lambayeque (Sicán) artist(s)
# Lambayeque (Sicán) artist(s)
# Hubert Robert
# Lambayeque (Sicán) artist(s)
# Zurich Pottery and Porcelain Factory
# Wu Xizai
# William Crowell
# Inca artist(s)
# Unknown
# Inca artist(s)
# Charles Nesensohn
# Nicole Eisenman
# Thomas Chapman
# Syd Carpenter
# Cornelis Engebrechtsz
# Auguste Renoir
# Anonymous, German, 18th century
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Ernest Eugène Appert
# Etienne Delaune
# Jacques Louis David
# Yukultji Napangati
# Nonggirrnga Marawili
# Nonggirrnga Marawili
# Nonggirrnga Marawili
# Nonggirrnga Marawili
# Miles Coolidge
# Louis C. Tiffany
# Qiu Anxiong
# Manohar
# Thomas Gainsborough
# Sir Henry Raeburn
# Oliver H. Willard
# Oliver H. Willard
# Hill and Adamson
# Nicolas Sorokine
# Oliver H. Willard
# Oliver H. Willard
# Oliver H. Willard
# Alma A. Pelot
# Thomas Rowlandson
# Hill and Adamson
# Qian Xuan
# Netherlandish Painter
# George Clisbee
# Georges Goursat [Sem]
# Currier & Ives
# Ferdinando Tacca
# Ferdinando Tacca
# Kelley Baking Company
# Lucas Cranach the Elder
# Thomas Chippendale
# Thomas Chippendale
# Edward Langley
# Andrea Briosco, called Riccio
# Jean Antoine Laurent
# Sir Joshua Reynolds
# Charles Parsons

# %%
first_results[1]
# Out:
# {'objectID': 473770,
#  'isHighlight': False,
#  'accessionNumber': '40.51.2',
#  'accessionYear': '1940',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/cl/original/cdi40-51-2s2.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/cl/web-large/cdi40-51-2s2.jpg',
#  'additionalImages': [],
#  'constituents': None,
#  'department': 'The Cloisters',
#  'objectName': 'Statue',
#  'title': 'King Clothar I',
#  'culture': 'French',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': '',
#  'artistPrefix': '',
#  'artistDisplayName': '',
#  'artistDisplayBio': '',
#  'artistSuffix': '',
#  'artistAlphaSort': '',
#  'artistNationality': '',
#  'artistBeginDate': '',
#  'artistEndDate': '',
#  'artistGender': '',
#  'artistWikidata_URL': '',
#  'artistULAN_URL': '',
#  'objectDate': 'ca. 1250',
#  'objectBeginDate': 1247,
#  'objectEndDate': 1253,
#  'medium': 'Limestone, originally polychromed.',
#  'dimensions': 'Overall: 74 1/2 in. (189.2 cm)',
#  'measurements': [{'elementName': 'Overall',
#    'elementDescription': None,
#    'elementMeasurements': {'Height': 189.23038}}],
#  'creditLine': 'The Cloisters Collection, 1940',
#  'geographyType': '',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': '',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Installations',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2024-11-20T04:52:58.38Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/473770',
#  'tags': [{'term': 'Doorways',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300002767',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q21263223'},
#   {'term': 'Kings',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300025481',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q12097'},
#   {'term': 'Men',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300025928',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q8441'}],
#  'objectWikidata_URL': 'https://www.wikidata.org/wiki/Q82295060',
#  'isTimelineWork': False,
#  'GalleryNumber': '001'}

# %%
titles = []
names = []
mediums = []
countries = []
accessionyears = []
urls = []
tags = []
objectwikidataurls = []

for item in first_hundred:
    title = item.get('title')
    titles.append(title)
    name = item.get('artistDisplayName')
    names.append(name)
    medium = item.get('medium')
    mediums.append(medium)
    country = item.get('country')
    countries.append(country)
    accessionyear = item.get('accessionYear')
    accessionyears.append(accessionyear)
    url = item.get('objectURL')
    urls.append(url)
    tag = item.get('tags')
    tags.append(tag)
    objectwikidataurl = item.get('objectWikidata_URL')
    objectwikidataurls.append(objectwikidataurl)

# %%
df = pd.DataFrame({
    'title': titles,
    'name': names,
    'medium': mediums,
    'country': countries,
    'accessionyear': accessionyears,
    'link': urls,
    'tag' : tags,
    'wikidata' : objectwikidataurls
})

# %%
df
# Out:
#                                                  title  \
# 0                                                 None
# 1                                       King Clothar I
# 2                                   The Demidoff Table
# 3                                        King Clovis I
# 4    Dance in a Subterranean Roundhouse at Clear La...
# ..                                                 ...
# 283  Adam and Eve in the Garden of Eden and Genesis...
# 284                                        Seated Faun
# 285                          Portrait of a Young Woman
# 286                                         The Vestal
# 287  Clipper Ship "Comet" of New York in a Hurrican...
#
#                               name                                  medium  \
# 0                             None                                    None
# 1                                       Limestone, originally polychromed.
# 2                Lorenzo Bartolini                                  Marble
# 3                                           Limestone with traces of paint
# 4                  Jules Tavernier                           Oil on canvas
# ..                             ...                                     ...
# 283                 Edward Langley  Etching and engraving with pen and ink
# 284  Andrea Briosco, called Riccio                                  Bronze
# 285           Jean Antoine Laurent                                   Ivory
# 286            Sir Joshua Reynolds          Stipple engraving; third state
# 287                Charles Parsons                 Hand-colored lithograph
#
#            country accessionyear  \
# 0             None          None
# 1                           1940
# 2                           1903
# 3           France          1940
# 4    United States          2016
# ..             ...           ...
# 283                         1967
# 284                         1964
# 285                         1925
# 286                         1924
# 287                         1951
#
#                                                   link  \
# 0                                                 None
# 1    https://www.metmuseum.org/art/collection/searc...
# 2    https://www.metmuseum.org/art/collection/searc...
# 3    https://www.metmuseum.org/art/collection/searc...
# 4    https://www.metmuseum.org/art/collection/searc...
# ..                                                 ...
# 283  https://www.metmuseum.org/art/collection/searc...
# 284  https://www.metmuseum.org/art/collection/searc...
# 285  https://www.metmuseum.org/art/collection/searc...
# 286  https://www.metmuseum.org/art/collection/searc...
# 287  https://www.metmuseum.org/art/collection/searc...
#
#                                                    tag  \
# 0                                                 None
# 1    [{'term': 'Doorways', 'AAT_URL': 'http://vocab...
# 2    [{'term': 'Boys', 'AAT_URL': 'http://vocab.get...
# 3    [{'term': 'Doorways', 'AAT_URL': 'http://vocab...
# 4    [{'term': 'Dancers', 'AAT_URL': 'http://vocab....
# ..                                                 ...
# 283                                               None
# 284  [{'term': 'Male Nudes', 'AAT_URL': 'http://voc...
# 285  [{'term': 'Portraits', 'AAT_URL': 'http://voca...
# 286                                               None
# 287                                               None
#
#                                      wikidata
# 0                                        None
# 1     https://www.wikidata.org/wiki/Q82295060
# 2    https://www.wikidata.org/wiki/Q116374165
# 3     https://www.wikidata.org/wiki/Q20201836
# 4     https://www.wikidata.org/wiki/Q78614308
# ..                                        ...
# 283
# 284
# 285   https://www.wikidata.org/wiki/Q19913816
# 286
# 287
#
# [288 rows x 8 columns]

# %%
output_file = "Met_sustainable_collection_info.csv"
df.to_csv(output_file, index=False)
print(f"Dataset saved to {output_file}")
# Out:
# Dataset saved to Met_sustainable_collection_info.csv
