# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Met_vases_collection_info.csv')

# %%
df
# Out:
#                                                  title                   name  \
# 0                                   Bamboo-shaped vase                    NaN
# 1               Terracotta skyphos (deep drinking cup)                    NaN
# 2                             Terracotta Megarian bowl                    NaN
# 3                         Vase with deer and pine tree                    NaN
# 4                       Vase with bamboo and plum tree                    NaN
# ..                                                 ...                    ...
# 202                                               Vase   Olive Forbes Sherman
# 203      Terracotta fragment of a kylix (drinking cup)            Apollodoros
# 204  Terracotta rim fragment of a kylix (drinking cup)               Onesimos
# 205                                      Pair of Vases  Belvedere Manufactory
# 206                 Vase (cuvette à fleurs Courteille)     Sèvres Manufactory
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          207 non-null    object
#  1   name           69 non-null     object
#  2   medium         206 non-null    object
#  3   country        16 non-null     object
#  4   accessionyear  207 non-null    int64
#  5   link           207 non-null    object
#  6   tag            117 non-null    object
#  7   wikidata       57 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 13.1+ KB

# %%
df.shape
# Out:
# (207, 8)

# %%
df.columns
# Out:
# Index(['title', 'name', 'medium', 'country', 'accessionyear', 'link', 'tag',
#        'wikidata'],
#       dtype='object')

# %%
df.sort_values('medium')
# Out:
#                                                  title                  name  \
# 175                                     Plum-tree vase                   NaN
# 0                                   Bamboo-shaped vase                   NaN
# 4                       Vase with bamboo and plum tree                   NaN
# 41   Vase with overlapping pattern and three bands ...                   NaN
# 92                                           Wall Vase                   NaN
# ..                                                 ...                   ...
# 61                                                Vase                   NaN
# 75                                                Vase                   NaN
# 74                                                Vase                   NaN
# 117                             Vase with Garden Scene                   NaN
# 202                                               Vase  Olive Forbes Sherman
#
# ...

# %%
df.sort_values('title')
# Out:
#                                                title                 name  \
# 198                                          Amphora                  NaN
# 35                                           Amphora                  NaN
# 197                                          Amphora                  NaN
# 151                                          Amphora                  NaN
# 150                                          Amphora                  NaN
# ..                                               ...                  ...
# 53                          Vase with poetric scenes                  NaN
# 82                                  Vase with reaper       Haviland & Co.
# 131                Vase with scenes of storm on land     Dihl et Guérhard
# 92                                         Wall Vase                  NaN
# 44   Winter Grove (Fuyu no kodachi) Flower Container  Okuyama Hōseki 奥山峰石
#
#                                                 medium country  accessionyear  \
# ...

# %%
counts = df.value_counts('medium')

# %%
amount = df.value_counts('medium')

# %%
counts.plot()
# Out:
# <Axes: xlabel='medium'>

# %%
df.value_counts('medium').plot()
# Out:
# <Axes: xlabel='medium'>

# %%
df.value_counts('medium').plot(kind='bar')
# Out:
# <Axes: xlabel='medium'>

# %%
df.value_counts('medium').nlargest(10).plot(kind='barh')
# Out:
# <Axes: ylabel='medium'>

# %%
df.value_counts('medium').nlargest(10).plot(kind='barh', xlabel='Frequency of Medium', title='Vases with Trees')
# Out:
# <Axes: title={'center': 'Vases with Trees'}, xlabel='Frequency of Medium', ylabel='medium'>

# %%
df.value_counts('medium').nlargest(10).plot(kind='pie', xlabel='Frequency of Medium', title='Vases with Trees Most Frequent Medium')
# Out:
# <Axes: title={'center': 'Vases with Trees Most Frequent Medium'}, ylabel='count'>
